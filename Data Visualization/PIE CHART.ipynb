# %% [markdown]
# # PIE CHART

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
subject="maths","physics","chem","english"
weightage=[20,10,15,5]
plt.pie(weightage,labels=subject,explode=(0,0,0.5,0),autopct='%1.1f%%',shadow=True)
plt.title("subject")
plt.show()
